# %% [markdown]
# # Try to explore earthquakes data on your own.
# ## What do they want to know about this data?

# %%
# import packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('oklahoma_earthquakes_1950-2017.csv', skiprows=2)
display(df.head())
# Out:
#                       time  latitude  longitude  depth  mag magType  nst  gap  \
# 0  1974-12-16 02:30:21.400    35.330    -97.480   10.0  2.6      ml  NaN  NaN
# 1  1975-09-13 01:25:02.800    34.139    -97.369    5.0  3.4      lg  NaN  NaN
# 2  1975-10-12 02:58:11.200    34.816    -97.406   20.0  3.2      lg  NaN  NaN
# 3  1975-11-29 14:29:40.900    34.521    -97.347    5.0  3.5      lg  NaN  NaN
# 4  1976-04-16 18:59:44.200    36.107    -99.875    5.0  3.4     NaN  NaN  NaN
#
#    dmin  rms  ... depthError magError magNst    status locationSource  \
# 0   NaN  NaN  ...        NaN      NaN    NaN  reviewed              m
# 1   NaN  NaN  ...        NaN      NaN    NaN  reviewed             us
# 2   NaN  NaN  ...        NaN      NaN    NaN  reviewed             us
# 3   NaN  NaN  ...        NaN      NaN    NaN  reviewed             us
# 4   NaN  NaN  ...        NaN      NaN    NaN  reviewed             us
#
#    magSource   loc_name  loc_admin1        loc_admin2 loc_cc
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8978 entries, 0 to 8977
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             8978 non-null   object
#  1   latitude         8978 non-null   float64
#  2   longitude        8978 non-null   float64
#  3   depth            8978 non-null   float64
#  4   mag              8978 non-null   float64
#  5   magType          8970 non-null   object
#  6   nst              722 non-null    float64
#  7   gap              8128 non-null   float64
#  8   dmin             916 non-null    float64
#  9   rms              8318 non-null   float64
#  10  net              8978 non-null   object
#  11  id               8978 non-null   object
#  12  updated          8978 non-null   object
#  13  place            8978 non-null   object
#  14  type             8978 non-null   object
#  15  horizontalError  6968 non-null   float64
# ...

# %% [markdown]
# ## Build a data dictionary
# time - time of occurence<br>
# latitude - location longtitude<br>
# longitude -location longtitude<br>
# depth - depth of the earthquake, the epicenter??<br>
# mag - magnitude in richters??<br>
# magType - type of earthquake?<br>
# nst -<br>
# gap -<br>
# dmin -<br>
# rms -<br>
# net - <br>
# id -<br>
# updated -<br>
# place -<br>
# type -<br>
# horizontalError -<br>
# depthError -<br>
# magError -<br>
# magNst -<br>
# status - revision status<br>
# locationSource - some kind of type for location source<br>
# magSource - some kind of type for mag source<br>
# loc_name - location name<br>
# loc_admin1 - location admin (state level)<br>
# loc_admin2 - location admin (county level)<br>
# loc_cc - location code<br>

# %%
# EDA
# 1. Number of earthquakes by year
# convert time to a datetime dtype
df['time'] = pd.to_datetime(df.time)

# create new columns for year and month
df['year'] = df['time'].dt.year
df['month'] = df['time'].dt.month

# visualize annual earthquakes
annual_eqs = df['time'].dt.year.value_counts().sort_index()
_ = annual_eqs.plot()
_ = plt.xlabel('year')
_ = plt.ylabel('earthquakes')
plt.show()

# %%
# 2. Magnitude by year
# visualize average magnitude
_ = sns.lineplot(data=df, x='year', y='mag', ci=None)
_.set_ylim(0,4)
plt.show()

# %%
# 3. Depth and mag by magType
